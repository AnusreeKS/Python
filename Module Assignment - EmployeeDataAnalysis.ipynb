# %% [markdown]
# # Employee Data Analysis - ABC Company

# %%
# Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading data set

# %%
df = pd.read_csv("ABC Employee Details.csv")

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Preprocessing: Replace height values with random numbers between 150 and 180

# %%
df["Height"] = np.random.randint(150, 181, size=len(df))

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     175     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2     John Holland  Boston Celtics      30       SG   27     177     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     175     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     171     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     163     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     180     256
# 456    Jeff Withey       Utah Jazz      24        C   26     152     231
# 457       Priyanka       Utah Jazz      34        C   25     175     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### 1.Employee Distribution by Team

# %%
team_distribution= df["Team"].value_counts()
team_distribution
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 458

# %%
team_percentage_slpit = ( team_distribution / len(df) )*100
team_percentage_slpit
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
plt.figure(figsize=(12,8))
sns.barplot(x= team_distribution.index, y= team_distribution.values, palette = "viridis")
plt.title("Employee Distribution by Team")
plt.xlabel("Team")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5764\2144339364.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= team_distribution.index, y= team_distribution.values, palette = "viridis")

# %%
plt.figure(figsize=(12,8))
sns.barplot(x= team_distribution.index, y= team_percentage_slpit.values, palette = "viridis")
plt.title("Percentage of Employee Distribution by Team")
plt.xlabel("Team")
plt.ylabel("Percentage Split")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5764\2798022647.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= team_distribution.index, y= team_percentage_slpit.values, palette = "viridis")

# %% [markdown]
# ### 2. Segregation by position

# %%
position_distribution = df["Position"].value_counts()
plt.figure(figsize=(8,5))
sns.barplot(x=position_distribution.index, y=position_distribution.values, palette="coolwarm")
plt.title("Employee Distribution by Position")
plt.xlabel("Position")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5764\1115298551.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=position_distribution.index, y=position_distribution.values, palette="coolwarm")

# %% [markdown]
# ### 3. Predominant Age Group

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Age"], bins=10, kde=True, color="blue")
plt.title("Age Distribution of Employees")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
age_distri=df["Age"].value_counts()

# %%
age_distri
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Highest Salary Expenditure (Team and Position)

# %%
salary_by_team = df.groupby("Team")["Salary"].sum().sort_values(ascending=False)
salary_by_position = df.groupby("Position")["Salary"].sum().sort_values(ascending=False)

# %%
highest_salary_team = df.groupby("Team")["Salary"].sum().idxmax()
print(f"Team with highest salary expenditure: {highest_salary_team}")
# Out:
# Team with highest salary expenditure: Cleveland Cavaliers

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=salary_by_team.index, y=salary_by_team.values, palette="magma")
plt.title("Total Salary Expenditure by Team")
plt.xlabel("Team")
plt.ylabel("Total Salary")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14400\3590742924.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=salary_by_team.index, y=salary_by_team.values, palette="magma")

# %%
highest_salary_position = df.groupby("Position")["Salary"].sum().idxmax()
print(f"Position with highest salary expenditure: {highest_salary_position}")
# Out:
# Position with highest salary expenditure: C

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=salary_by_position.index, y=salary_by_position.values, palette="cividis")
plt.title("Total Salary Expenditure by Position")
plt.xlabel("Position")
plt.ylabel("Total Salary")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14400\67658255.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=salary_by_position.index, y=salary_by_position.values, palette="cividis")

# %% [markdown]
# ### 5. Correlation between Age and Salary

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=df["Age"], y=df["Salary"], alpha=0.6)
plt.title("Correlation between Age and Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ### Save processed dataset

# %%
df.to_csv("Processed_Employee_Data.csv", index=False)
print("Processed dataset saved as 'Processed_Employee_Data.csv'")
# Out:
# Processed dataset saved as 'Processed_Employee_Data.csv'

# %%
print(pd.read_csv("Processed_Employee_Data.csv"))
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     175     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2     John Holland  Boston Celtics      30       SG   27     177     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     175     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     171     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     163     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     180     256
# 456    Jeff Withey       Utah Jazz      24        C   26     152     231
# 457       Priyanka       Utah Jazz      34        C   25     175     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...
